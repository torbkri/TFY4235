# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv
import tensorflow as tf
import keras

# %%
img = cv.imread("/Users/torbjornkringeland/Desktop/NTNU/6/TFY4235/SFD-STUDENTS/exampleSignature.png", cv.IMREAD_GRAYSCALE)

# %%
img = tf.convert_to_tensor(img, dtype=tf.float32)

# %%
img.shape
# Out:
# TensorShape([277, 264])

# %%
Batch_size = B
