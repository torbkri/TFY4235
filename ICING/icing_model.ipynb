# %% [markdown]
# ## 2D-Icing model

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import maxwell, norm
from numba import njit

# %%
@njit
def E(J:float, s1:int, s2:int)->float:
    return J * (s1 * s2)
