# %% [markdown]
# # Reproduce plots

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.patheffects as patheffects

from plotting import *

# %%
# Some constants
L = 40
n_sweeps = 10000

T_values = np.linspace(1, 4, 300)

snapshotvals = [1.5, 2.3, 2.5]

non_impurity_directory = "simulation_data_wo_impurities"
impurity_directory = "simulation_data_w_impurities"
w_H_directory = "simulation_data_w_H"

# %%
# Task 3.1.1
temps = [2.1, 2.3, 2.5]

get_plot_task_3_1_1(L, n_sweeps, temps)

# %%
# Task 3.1.2
# Requires that the simulation data is already generated and saved correctly

M_lst = np.load(f'{non_impurity_directory}/M_Tvals{T_values.shape[0]}_L{L}_Nsweeps{n_sweeps}.npy')
E_final_lst = np.load(f'{non_impurity_directory}/E_Tvals{T_values.shape[0]}_L{L}_Nsweeps{n_sweeps}.npy')
E_var_lst = np.load(f'{non_impurity_directory}/E_var_Tvals{T_values.shape[0]}_L{L}_Nsweeps{n_sweeps}.npy')
snaps = np.load(f'{non_impurity_directory}/snapshots{snapshotvals}_Tvals{T_values.shape[0]}_L{L}_Nsweeps{n_sweeps}.npy')

plot_M_E(L, T_values, M_lst, E_final_lst)

plot_snapshots_3_1_2(snaps, snapshotvals)
# Out:
# 0

# %%
# Task 3.1.3
# Also requires that the simulation data is already generated and saved correctly
get_plot_task_3_1_3(T_values, n_sweeps)
# Out:
# 0

# %%
# Task 3.1.4
# Also requires that the simulation data is already generated and saved correctly
p_values = [0.01, 0.1, 0.3]

get_plot_3_1_4(p_values, T_values, L, n_sweeps)
# Out:
# 0

# %%
# Task 3.1.5
# Simulated Annealing
# Darker squares are frozen in impurities
T_start = 5
T_end = 0.1
delta_T = (T_start - T_end) / 10000

get_plot_and_data_3_1_5(T_start, T_end, delta_T, L, p_values)
# Out:
# 0
